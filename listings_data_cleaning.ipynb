# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
filepath = os.path.join("listings.csv")

# %%
listings_df = pd.read_csv(filepath)

listings_df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (43,61,62,94,95) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      id                        listing_url       scrape_id last_scraped  \
# 0  2060  https://www.airbnb.com/rooms/2060  20200608144437   2020-06-09
# 1  2595  https://www.airbnb.com/rooms/2595  20200608144437   2020-06-09
# 2  3831  https://www.airbnb.com/rooms/3831  20200608144437   2020-06-09
# 3  5099  https://www.airbnb.com/rooms/5099  20200608144437   2020-06-09
# 4  5121  https://www.airbnb.com/rooms/5121  20200608144437   2020-06-09
#
#                                                 name  \
# 0                                         Modern NYC
# 1                              Skylit Midtown Castle
# 2  Whole flr w/private bdrm, bath & kitchen(pls r...
# 3          Large Cozy 1 BR Apartment In Midtown East
# 4                                    BlissArtsSpace!
#
#                                              summary  \
# 0                                                NaN
# 1  Beautiful, spacious skylit studio in the heart...
# 2  Enjoy 500 s.f. top floor in 1899 brownstone, w...
# 3  My large 1 bedroom apartment has a true New Yo...
# 4                                                NaN
#
#                                                space  \
# 0  Lovely, spacious, sunny 1 BR apartment in 6th ...
# 1  - Spacious (500+ft²), immaculate and nicely fu...
# 2  We host on the entire top floor of our double-...
# 3  I have a large 1 bedroom apartment centrally l...
# 4  HELLO EVERYONE AND THANKS FOR VISITING BLISS A...
#
#                                          description experiences_offered  \
# 0  Lovely, spacious, sunny 1 BR apartment in 6th ...                none
# 1  Beautiful, spacious skylit studio in the heart...                none
# 2  Enjoy 500 s.f. top floor in 1899 brownstone, w...                none
# 3  My large 1 bedroom apartment has a true New Yo...                none
# 4  HELLO EVERYONE AND THANKS FOR VISITING BLISS A...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0                                                NaN  ...                f
# 1  Centrally located in the heart of Manhattan ju...  ...                f
# 2  Just the right mix of urban center and local n...  ...                f
# 3  My neighborhood in Midtown East is called Murr...  ...                f
# 4                                                NaN  ...                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f                     flexible
# 1                        f  strict_14_with_grace_period
# 2                        f                     flexible
# 3                        f                     moderate
# 4                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             t                                t
# 2                             f                                f
# 3                             t                                t
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               2
# 2                               1
# 3                               1
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            2
# 2                                            1
# 3                                            1
# 4                                            0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            1
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.01
# 1                                            0               0.37
# 2                                            0               4.64
# 3                                            0               0.58
# 4                                            0               0.37
#
# [5 rows x 106 columns]

# %%
listings_df.count()
# Out:
# id                                              49530
# listing_url                                     49530
# scrape_id                                       49530
# last_scraped                                    49530
# name                                            49512
#                                                 ...
# calculated_host_listings_count                  49530
# calculated_host_listings_count_entire_homes     49530
# calculated_host_listings_count_private_rooms    49530
# calculated_host_listings_count_shared_rooms     49530
# reviews_per_month                               38211
# Length: 106, dtype: int64

# %%
listings_df.columns.tolist()
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'requires_license',
#  'license',
#  'jurisdiction_names',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month']

# %%
cleancol_df = listings_df.drop(['listing_url', 
                                'scrape_id', 
                                'last_scraped', 
                                'experiences_offered', 
                                'thumbnail_url', 
                                'medium_url', 
                                'picture_url', 
                                'xl_picture_url', 
                                'host_url', 
                                'host_name', 
                                'host_thumbnail_url', 
                                'host_picture_url', 
                                'host_has_profile_pic', 
                                'street', 
                                'market', 
                                'smart_location', 
                                'country', 
                                'minimum_minimum_nights', 
                                'maximum_minimum_nights', 
                                'minimum_maximum_nights', 
                                'minimum_nights_avg_ntm', 
                                'maximum_nights_avg_ntm',
                                'maximum_maximum_nights',
                                'square_feet',
                                'calendar_updated', 
                                'has_availability', 
                                'availability_30', 
                                'availability_60', 
                                'availability_90', 
                                'calendar_last_scraped', 
                                'number_of_reviews_ltm', 
                                'first_review', 
                                'last_review', 
                                'review_scores_accuracy', 
                                'review_scores_cleanliness', 
                                'review_scores_checkin', 
                                'review_scores_communication', 
                                'review_scores_location', 
                                'requires_license', 
                                'license', 
                                'jurisdiction_names', 
                                'instant_bookable', 
                                'is_business_travel_ready', 
                                'cancellation_policy', 
                                'require_guest_profile_picture', 
                                'require_guest_phone_verification', 
                                'calculated_host_listings_count', 
                                'calculated_host_listings_count_entire_homes', 
                                'calculated_host_listings_count_private_rooms', 
                                'calculated_host_listings_count_shared_rooms', 
                                'reviews_per_month'], axis=1)

# %%
clean_list = cleancol_df.columns.tolist()
len(clean_list)
# Out:
# 55

# %%
clean_list
# Out:
# ['id',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'host_id',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_identity_verified',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'country_code',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'availability_365',
#  'number_of_reviews',
#  'review_scores_rating',
#  'review_scores_value']

# %%
cleancol_df.count()
# Out:
# id                              49530
# name                            49512
# summary                         47035
# space                           35419
# description                     48240
# neighborhood_overview           32106
# notes                           19700
# transit                         32393
# access                          25868
# interaction                     29479
# house_rules                     29627
# host_id                         49530
# host_since                      49524
# host_location                   49385
# host_about                      29741
# host_response_time              22214
# host_response_rate              22214
# host_acceptance_rate            34134
# host_is_superhost               49524
# host_neighbourhood              41774
# host_listings_count             49524
# host_total_listings_count       49524
# host_verifications              49530
# host_identity_verified          49524
# neighbourhood                   49519
# neighbourhood_cleansed          49530
# neighbourhood_group_cleansed    49530
# city                            49388
# state                           49525
# zipcode                         49101
# country_code                    49530
# latitude                        49530
# longitude                       49530
# is_location_exact               49530
# property_type                   49530
# room_type                       49530
# accommodates                    49530
# bathrooms                       49453
# bedrooms                        49388
# beds                            48992
# bed_type                        49518
# amenities                       49530
# price                           49530
# weekly_price                     5292
# monthly_price                    4566
# security_deposit                32347
# cleaning_fee                    38668
# guests_included                 49530
# extra_people                    49530
# minimum_nights                  49530
# maximum_nights                  49530
# availability_365                49530
# number_of_reviews               49530
# review_scores_rating            37243
# review_scores_value             37194
# dtype: int64

# %%
cleancol_df.dtypes
# Out:
# id                                int64
# name                             object
# summary                          object
# space                            object
# description                      object
# neighborhood_overview            object
# notes                            object
# transit                          object
# access                           object
# interaction                      object
# house_rules                      object
# host_id                           int64
# host_since                       object
# host_location                    object
# host_about                       object
# host_response_time               object
# host_response_rate               object
# host_acceptance_rate             object
# host_is_superhost                object
# host_neighbourhood               object
# host_listings_count             float64
# host_total_listings_count       float64
# host_verifications               object
# host_identity_verified           object
# neighbourhood                    object
# neighbourhood_cleansed           object
# neighbourhood_group_cleansed     object
# city                             object
# state                            object
# zipcode                          object
# country_code                     object
# latitude                        float64
# longitude                       float64
# is_location_exact                object
# property_type                    object
# room_type                        object
# accommodates                      int64
# bathrooms                       float64
# bedrooms                        float64
# beds                            float64
# bed_type                         object
# amenities                        object
# price                            object
# weekly_price                     object
# monthly_price                    object
# security_deposit                 object
# cleaning_fee                     object
# guests_included                   int64
# extra_people                     object
# minimum_nights                    int64
# maximum_nights                    int64
# availability_365                  int64
# number_of_reviews                 int64
# review_scores_rating            float64
# review_scores_value             float64
# dtype: object

# %%
cleancol_df['is_location_exact']
# Out:
# 0        t
# 1        f
# 2        t
# 3        f
# 4        f
#         ..
# 49525    t
# 49526    t
# 49527    t
# 49528    t
# 49529    t
# Name: is_location_exact, Length: 49530, dtype: object

# %%
cleancol_df.isna().sum()
# Out:
# 0

# %%
exact_location_df = cleancol_df.loc[(cleancol_df["is_location_exact"] == "t"), :]

exact_location_df
# Out:
#              id                                               name  \
# 0          2060                                         Modern NYC
# 2          3831  Whole flr w/private bdrm, bath & kitchen(pls r...
# 5          5136           Spacious Brooklyn Duplex, Patio + Garden
# 6          5178                   Large Furnished Room Near B'way
# 7          5203                 Cozy Clean Guest Room - Family Apt
# ...         ...                                                ...
# 49525  43702714    Spacious and Luxurious Noho 3 Bedroom Apartment
# 49526  43702765         2-bedroom entire place for you in Bushwick
# 49527  43703128  Simple Spacious Manhattan Room for 2Near 2,3 T...
# 49528  43703156                Cosy Room Available in East Village
# 49529  43703359      A+ Location Deluxe Studio (Queen Bed & Futon)
#
#                                                  summary  \
# 0                                                    NaN
# 2      Enjoy 500 s.f. top floor in 1899 brownstone, w...
# 5      We welcome you to stay in our lovely 2 br dupl...
# 6      Please don’t expect the luxury here just a bas...
# 7      Our best guests are seeking a safe, clean, spa...
# ...                                                  ...
# 49525  Beautiful spacious NoHo apartment. Minutes awa...
# 49526  2-bedroom in Bushwick, Brooklyn, 1000 sqf, 2 b...
# 49527  This is an affordable master bedroom for 2 in ...
# 49528  10 minutes from L train and F Train Coffee, re...
# 49529  Our apartment is located in the center of Manh...
#
#                                                    space  \
# 0      Lovely, spacious, sunny 1 BR apartment in 6th ...
# 2      We host on the entire top floor of our double-...
# 5      Sleeps 4 comfortably- king bed in master bedro...
# 6      You will use one large, furnished, private roo...
# 7      Stay in my family's little  guest room and enj...
# ...                                                  ...
# 49525                                                NaN
# 49526                                                NaN
# 49527  *************************************** Curren...
# 49528                                                NaN
# 49529  * We want everyone to have a comfortable place...
#
#                                              description  \
# 0      Lovely, spacious, sunny 1 BR apartment in 6th ...
# 2      Enjoy 500 s.f. top floor in 1899 brownstone, w...
# 5      We welcome you to stay in our lovely 2 br dupl...
# 6      Please don’t expect the luxury here just a bas...
# 7      Our best guests are seeking a safe, clean, spa...
# ...                                                  ...
# 49525  Beautiful spacious NoHo apartment. Minutes awa...
# 49526  2-bedroom in Bushwick, Brooklyn, 1000 sqf, 2 b...
# 49527  This is an affordable master bedroom for 2 in ...
# 49528  10 minutes from L train and F Train Coffee, re...
# 49529  Our apartment is located in the center of Manh...
#
#                                    neighborhood_overview  \
# 0                                                    NaN
# 2      Just the right mix of urban center and local n...
# 5                                                    NaN
# 6        Theater district, many restaurants around here.
# 7      Our neighborhood is full of restaurants and ca...
# ...                                                  ...
# 49525                                                NaN
# 49526                                                NaN
# 49527  Harlem is one of the largest areas in Manhatta...
# 49528                                                NaN
# 49529  We are located inside this beautiful national ...
#
#                                                    notes  \
# 0                                                    NaN
# 2      Same day reservations are welcome, but you MUS...
# 5      We have two small children- so there are many ...
# 6      Reservation should be made at least a few days...
# 7      Because we are an active family, I guarantee t...
# ...                                                  ...
# 49525                                                NaN
# 49526                                                NaN
# 49527  Brand new sheets, pillowcases, and comfortable...
# 49528                                                NaN
# 49529  - Our apartment is inside "Class B" Hotel cert...
#
#                                                  transit  \
# 0                                                    NaN
# 2      B52 bus for a 10-minute ride to downtown Brook...
# 5                                                    NaN
# 6                                                    NaN
# 7      The number 1 train stops at 110th Street/Cathe...
# ...                                                  ...
# 49525                                                NaN
# 49526                                                NaN
# 49527  2,3 Train 5 mins to 134 St  Station 7 mins to ...
# 49528                                                NaN
# 49529  It’s easy to get around the city thanks to our...
#
#                                                   access  \
# 0                                                    NaN
# 2      You will have the private, exclusive use of an...
# 5      Entire duplex apt is free to use, except for c...
# 6      Bathroom is shared with the host but the kitch...
# 7      Guests will be able to come and go as they nee...
# ...                                                  ...
# 49525                                                NaN
# 49526                                                NaN
# 49527  There is a kitchen with kitchenware and bathro...
# 49528                                                NaN
# 49529                                                NaN
#
#                                              interaction  ...  \
# 0                                                    NaN  ...
# 2      We'll be around, but since you have the top fl...  ...
# 5      guests can email me during their stay and can ...  ...
# 6                                                    NaN  ...
# 7      My modern family is super busy with lots of co...  ...
# ...                                                  ...  ...
# 49525                                                NaN  ...
# 49526                            Email and text any time  ...
# 49527  I’m taking offs on Sundays. I will reply on Mo...  ...
# 49528                                                NaN  ...
# 49529  Unless there are problems, we will leave you a...  ...
#
#       security_deposit  cleaning_fee guests_included extra_people  \
# 0                  NaN           NaN               1        $0.00
# 2              $500.00           NaN               1        $0.00
# 5                  NaN           NaN               4       $25.00
# 6                  NaN        $15.00               1       $12.00
# 7                  NaN           NaN               1        $0.00
# ...                ...           ...             ...          ...
# 49525              NaN           NaN               1        $0.00
# 49526            $0.00        $50.00               1        $0.00
# 49527            $0.00        $30.00               1        $0.00
# 49528              NaN           NaN               1        $0.00
# 49529          $200.00        $80.00               2       $15.00
#
#       minimum_nights maximum_nights availability_365 number_of_reviews  \
# 0                  1            730              365                 1
# 2                  1            730              276               322
# 5                 14           1125              358                 1
# 6                  2             14              294               473
# 7                  2             14                0               118
# ...              ...            ...              ...               ...
# 49525              3           1125              365                 0
# 49526              3           1125              135                 0
# 49527             28            365                8                 0
# 49528              2              2               12                 0
# 49529              1            365              230                 0
#
#       review_scores_rating review_scores_value
# 0                     80.0                 NaN
# 2                     89.0                 8.0
# 5                     97.0                10.0
# 6                     84.0                 9.0
# 7                     98.0                10.0
# ...                    ...                 ...
# 49525                  NaN                 NaN
# 49526                  NaN                 NaN
# 49527                  NaN                 NaN
# 49528                  NaN                 NaN
# 49529                  NaN                 NaN
#
# [46939 rows x 55 columns]

# %%
exact_location_df.count()
# Out:
# id                              46939
# name                            46924
# summary                         44626
# space                           33645
# description                     45759
# neighborhood_overview           30514
# notes                           18664
# transit                         30811
# access                          24519
# interaction                     28073
# house_rules                     28090
# host_id                         46939
# host_since                      46933
# host_location                   46806
# host_about                      28183
# host_response_time              21113
# host_response_rate              21113
# host_acceptance_rate            32440
# host_is_superhost               46933
# host_neighbourhood              40930
# host_listings_count             46933
# host_total_listings_count       46933
# host_verifications              46939
# host_identity_verified          46933
# neighbourhood                   46928
# neighbourhood_cleansed          46939
# neighbourhood_group_cleansed    46939
# city                            46812
# state                           46936
# zipcode                         46918
# country_code                    46939
# latitude                        46939
# longitude                       46939
# is_location_exact               46939
# property_type                   46939
# room_type                       46939
# accommodates                    46939
# bathrooms                       46873
# bedrooms                        46812
# beds                            46430
# bed_type                        46927
# amenities                       46939
# price                           46939
# weekly_price                     5021
# monthly_price                    4314
# security_deposit                30727
# cleaning_fee                    36692
# guests_included                 46939
# extra_people                    46939
# minimum_nights                  46939
# maximum_nights                  46939
# availability_365                46939
# number_of_reviews               46939
# review_scores_rating            35378
# review_scores_value             35329
# dtype: int64

# %%
exact_location_df.to_csv('listings_cleaned.csv')

# %%
exact_location_df.dtypes
# Out:
# id                                int64
# name                             object
# summary                          object
# space                            object
# description                      object
# neighborhood_overview            object
# notes                            object
# transit                          object
# access                           object
# interaction                      object
# house_rules                      object
# host_id                           int64
# host_since                       object
# host_location                    object
# host_about                       object
# host_response_time               object
# host_response_rate               object
# host_acceptance_rate             object
# host_is_superhost                object
# host_neighbourhood               object
# host_listings_count             float64
# host_total_listings_count       float64
# host_verifications               object
# host_identity_verified           object
# neighbourhood                    object
# neighbourhood_cleansed           object
# neighbourhood_group_cleansed     object
# city                             object
# state                            object
# zipcode                          object
# country_code                     object
# latitude                        float64
# longitude                       float64
# is_location_exact                object
# property_type                    object
# room_type                        object
# accommodates                      int64
# bathrooms                       float64
# bedrooms                        float64
# beds                            float64
# bed_type                         object
# amenities                        object
# price                            object
# weekly_price                     object
# monthly_price                    object
# security_deposit                 object
# cleaning_fee                     object
# guests_included                   int64
# extra_people                     object
# minimum_nights                    int64
# maximum_nights                    int64
# availability_365                  int64
# number_of_reviews                 int64
# review_scores_rating            float64
# review_scores_value             float64
# dtype: object

# %%
#Create function to iterate through column and take out unnecessary "$" for example price has a few values that
# are objects because of "$" instead of being an integer.

# %%
def price_fixer(col_name, )
